# %% [markdown]
# # Titanic Data Analysis
# **What factors made people more likely to survive?**

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('titanic_data_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked embarked_port          ses  \
# 0      0         A/5 21171   7.2500   NaN        S   Southampton  Lower class
# 1      0          PC 17599  71.2833   C85        C     Cherbourg  Upper class
# ...

# %% [markdown]
# ## Explore Passenger Class

# %%
sns.factorplot(data=df, x='passenger_group', y='Survived', kind='bar', order=['Men','Women','Children'], ci=95)

# %%
sns.factorplot(data=df, x='Pclass', y='Survived', kind='bar', ci=95)

# %%
sns.countplot(data=df, x='Pclass', hue='passenger_group')

# %%
sns.factorplot(data=df, x='Pclass', y='Survived', col='passenger_group', kind='bar')

# %% [markdown]
# ## Explore Embarked Port

# %%
sns.factorplot(data=df, x='embarked_port', y='Survived', kind='bar', ci=95)

# %%
sns.factorplot(data=df, x='embarked_port', y='Survived', kind='bar', col='Pclass', ci=95)

# %% [markdown]
# ## Explore Familes

# %%
sns.factorplot(data=df, x='has_family', y='Survived', kind='bar', ci=95)

# %%
sns.factorplot(data=df, x='has_family', y='Survived', kind='bar', col='passenger_group', ci=95)

# %% [markdown]
# ## Explore Fares

# %%
sns.violinplot(data=df, y='Fare', x='Survived')

# %% [markdown]
# ## Explore Age

# %%
sns.violinplot(data=df, y='Age', x='Survived')
